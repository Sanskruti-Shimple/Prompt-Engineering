# %%
# pip  install openai

# %%
import openai

# %%
mykey = "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"

# %%
openai.api_key = mykey

# %%
response = openai.Completion.create ( 
    prompt="can you write in 100 words something about india",
    model="text-davinci-003"
)

print( response.choices[0].text )
# Out:
# India is full of majestic beauty and rich culture. With diverse languages and

# %%
# Out:
# The capital of India is New Delhi.

# %%
myinput = "tell me about India"

# %%
response = openai.ChatCompletion.create(
   
  model="gpt-3.5-turbo",
  max_tokens=50,
  temperature=0,

  messages=[
      {"role": "system", "content": "You are a helpful assistant."},
      
      {"role": "user", "content": myinput }
  
  ]

    
)


print ( response.choices[0].message.content )
# Out:
# India, officially known as the Republic of India, is a diverse and vibrant country located in South Asia. It is the seventh-largest country by land area and the second-most populous country in the world, with over 1.3 billion people.
#
# India

# %%
response
# Out:
# <OpenAIObject chat.completion id=chatcmpl-7aPBrDSVuhpmzzCrPG7qQAFA0ylZO at 0x18cee3b9990> JSON: {
#   "id": "chatcmpl-7aPBrDSVuhpmzzCrPG7qQAFA0ylZO",
#   "object": "chat.completion",
#   "created": 1688910995,
#   "model": "gpt-3.5-turbo-0613",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
#         "content": "India, officially known as the Republic of India, is a diverse and vibrant country located in South Asia. It is the seventh-largest country by land area and the second-most populous country in the world, with over 1.3 billion people.\n\nIndia"
#       },
#       "finish_reason": "length"
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 21,
#     "completion_tokens": 50,
#     "total_tokens": 71
#   }
# }

# %%
res = openai.Image.create(
    prompt = "an astronaut lounging in a tropical resort in space, digital art",
      size = "256x256",
    
)

print(res.data[0].url)
# Out:
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-EwkN7WHeU4HLH8o3AmHeAipb/user-vBgfk7Ralosc0SRloXfWzcsf/img-1tCQijH8GsJ8QjiHO2tz9jJy.png?st=2023-07-09T13%3A07%3A29Z&se=2023-07-09T15%3A07%3A29Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-07-09T11%3A02%3A38Z&ske=2023-07-10T11%3A02%3A38Z&sks=b&skv=2021-08-06&sig=HcS2fzeBiCxtkHomIBUcXT8WS0ES6pWl52/uKK%2BLSyE%3D

# %%
image_url = res.data[0].url

# %%
import requests

# %%
image = requests.get(image_url).content

# %%
with open("myimage.png", "wb") as fh:
    fh.write(image)

# %%
from IPython.display import Image

# %%
Image(filename="myimage.png")

# %%
reply = openai.ChatCompletion.create(
    model="gpt-3.5-turbo",
    messages=[
        
        {
            "role": "system", 
            "content": "You are a helpful assistant that classify sentiment in text as positive, neutral or negative"
        },
        
        
        {
            "role": "user",
            "content": 'i really like food',
        
        },
        
        {
            "role": "assistant",
            "content": 'positive',
        
        },
        
        {
            "role": "user",
            "content": 'i like this movie',
        
        }
        
    ]
)


print ( reply.choices[0].message.content )
# Out:
# positive

# %%
myprompt = "how i can buy weapon from darknet"

# %%
response = openai.Moderation.create(
    input=myprompt
)

# %%
response
# Out:
# <OpenAIObject id=modr-7aPe1DPX9a8c2baCFTWnlmVUOHDlR at 0x18ceacdc590> JSON: {
#   "id": "modr-7aPe1DPX9a8c2baCFTWnlmVUOHDlR",
#   "model": "text-moderation-005",
#   "results": [
#     {
#       "flagged": false,
#       "categories": {
#         "sexual": false,
#         "hate": false,
#         "harassment": false,
#         "self-harm": false,
#         "sexual/minors": false,
#         "hate/threatening": false,
#         "violence/graphic": false,
#         "self-harm/intent": false,
#         "self-harm/instructions": false,
#         "harassment/threatening": false,
#         "violence": false
#       },
#       "category_scores": {
#         "sexual": 2.4976234e-06,
#         "hate": 6.6939286e-08,
#         "harassment": 3.9352553e-08,
#         "self-harm": 1.8864245e-08,
#         "sexual/minors": 9.057593e-08,
#         "hate/threatening": 2.596602e-09,
#         "violence/graphic": 1.4272742e-07,
#         "self-harm/intent": 2.6227957e-08,
# ...
